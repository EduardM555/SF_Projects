# %%
import pandas as pd

print(pd.__name__)
# Out:
# pandas

# %%
# import pandas as pd
countries = pd.Series(
    data = ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    index = ['UK', 'CA', 'US', 'RU', 'UA', 'BY', 'KZ'],
    name='countries'
)
display(countries)
# Out:
# UK       Англия
# CA       Канада
# US          США
# RU       Россия
# UA      Украина
# BY     Беларусь
# KZ    Казахстан
# Name: countries, dtype: object

# %%
countries = pd.Series({
    'UK': 'Англия',
    'CA': 'Канада',
    'US' : 'США',
    'RU': 'Россия',
    'UA': 'Украина',
    'BY': 'Беларусь',
    'KZ': 'Казахстан'},
    name = 'countries'
)
display(countries)
# Out:
# UK       Англия
# CA       Канада
# US          США
# RU       Россия
# UA      Украина
# BY     Беларусь
# KZ    Казахстан
# Name: countries, dtype: object

# %%
print(countries.loc['UK'])
print(countries.loc[['UK', 'US', 'RU']])
# Out:
# Англия
# UK    Англия
# US       США
# RU    Россия
# Name: countries, dtype: object

# %%
print(countries.iloc[6])
print(countries.iloc[6:7])
print(countries.iloc[:4])
print(countries.iloc[[0, 2, 3]])
# Out:
# Казахстан
# KZ    Казахстан
# Name: countries, dtype: object
# UK    Англия
# CA    Канада
# US       США
# RU    Россия
# Name: countries, dtype: object
# UK    Англия
# US       США
# RU    Россия
# Name: countries, dtype: object

# %%
fruits = pd.Series(
    ['Apple', 'Banana'],
    ['A', 'B'],
    name='FRUITS')
fruits
# Out:
# A     Apple
# B    Banana
# Name: FRUITS, dtype: object

# %%
countries_df = pd.DataFrame({
    'country': ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    'population': [56.29, 38.05, 322.28, 146.24, 45.5, 9.5, 17.04],
    'square': [133396, 9984670, 9826630, 17125191, 603628, 207600, 2724902]
})
display(countries_df)
countries_df.index = ['UK', 'CA', 'US', 'RU', 'UA', 'BY', 'KZ']
display(countries_df)
# Out:
#      country  population    square
# 0     Англия       56.29    133396
# 1     Канада       38.05   9984670
# 2        США      322.28   9826630
# 3     Россия      146.24  17125191
# 4    Украина       45.50    603628
# 5   Беларусь        9.50    207600
# 6  Казахстан       17.04   2724902
#       country  population    square
# UK     Англия       56.29    133396
# CA     Канада       38.05   9984670
# US        США      322.28   9826630
# RU     Россия      146.24  17125191
# UA    Украина       45.50    603628
# BY   Беларусь        9.50    207600
# KZ  Казахстан       17.04   2724902

# %%
countries_df = pd.DataFrame(
    data=[
        ['Англия', 56.29, 133396],
        ['Канада', 38.05, 9984670],
        ['США', 322.28, 9826630],
        ['Россия', 146.24, 17125191],
        ['Украина', 45.5, 603628],
        ['Беларусь', 9.5, 207600],
        ['Казахстан', 17.04, 2724902]
    ],
    columns=['country', 'population', 'square'],
    index=['UK', 'CA', 'US', 'RU', 'UA', 'BY', 'KZ']
)
countries_df
# Out:
#       country  population    square
# UK     Англия       56.29    133396
# CA     Канада       38.05   9984670
# US        США      322.28   9826630
# RU     Россия      146.24  17125191
# UA    Украина       45.50    603628
# BY   Беларусь        9.50    207600
# KZ  Казахстан       17.04   2724902

# %%
display(countries_df.square)
# Out:
# UK      133396
# CA     9984670
# US     9826630
# RU    17125191
# UA      603628
# BY      207600
# KZ     2724902
# Name: square, dtype: int64

# %%
print(countries_df['population'])
# Out:
# UK     56.29
# CA     38.05
# US    322.28
# RU    146.24
# UA     45.50
# BY      9.50
# KZ     17.04
# Name: population, dtype: float64

# %%
countries_df.loc[['RU', 'UK'], ['population', 'square']]
# Out:
#     population    square
# RU      146.24  17125191
# UK       56.29    133396

# %%
countries_df.iloc[[-4, 0], 1:3]
# Out:
#     population    square
# RU      146.24  17125191
# UK       56.29    133396

# %%
# 4. Работа с различными источниками данных в Pandas

countries_df = pd.DataFrame({
    'country': ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    'population': [56.29, 38.05, 322.28, 146.24, 45.5, 9.5, 17.04],
    'square': [133396, 9984670, 9826630, 17125191, 603628, 207600, 2724902]
})

countries_df.to_csv(path_or_buf='data/countries.csv', sep=';', index=False)

# %%
countries_data = pd.read_csv('data/countries.csv', sep=';', names=['population', 'country'])
print(countries_data)
# Out:
#            population   country
# country    population    square
# Англия          56.29    133396
# Канада          38.05   9984670
# США            322.28   9826630
# Россия         146.24  17125191
# Украина          45.5    603628
# Беларусь          9.5    207600
# Казахстан       17.04   2724902

# %%
data = pd.read_csv('https://raw.githubusercontent.com/esabunor/MLWorkspace/master/melb_data.csv', names=['Suburb', 'Address'])
display(data)
# Out:
#                                                                                                                                                                                                                                    Suburb  \
# NaN     Suburb       Address          Rooms Type Price     Method SellerG    Date       Distance Postcode Bedroom2 Bathroom Car Landsize BuildingArea YearBuilt CouncilArea Lattitude           Longtitude                     Regionname
# 1.0     Abbotsford   85 Turner St     2     h    1480000.0 S      Biggin     3/12/2016  2.5      3067.0   2.0      1.0      1.0 202.0    NaN          NaN       Yarra       -37.7996            144.9984            Northern Metropolitan
# 2.0     Abbotsford   25 Bloomburg St  2     h    1035000.0 S      Biggin     4/02/2016  2.5      3067.0   2.0      1.0      0.0 156.0    79.0         1900.0    Yarra       -37.8079            144.9934            Northern Metropolitan
# ...

# %%
table_xlsx = pd.read_excel('data/table.xlsx', skiprows=2)
table_xlsx = table_xlsx.dropna(axis=1, how='all')
table_xlsx.to_excel('data/table_from_df.xlsx', index=False)
display(table_xlsx)
# Out:
#               Парметры   Значение1   Значение2   Значение3
# 0           Ст-ть авто  2500000.00  2000000.00  2600000.00
# 1                   ПВ   800000.00   800000.00   800000.00
# 2  Сумма кредита за ТС  1700000.00  1200000.00  1800000.00
# 3    Срок кредита, мес       84.00       84.00       84.00
# 4    Процентная ставка        0.17        0.15        0.14
# 5      Название тарифа         NaN         NaN         NaN

# %%
tbl = pd.read_excel('data/table_from_df.xlsx', )
tbl = tbl.fillna(0)
# tbl['Значение'].fillna(0)
display(tbl)
tbl.to_csv('data/table_from_df.csv', index=False)
tbl.iloc[4, 0]
# Out:
#               Парметры   Значение1   Значение2   Значение3
# 0           Ст-ть авто  2500000.00  2000000.00  2600000.00
# 1                   ПВ   800000.00   800000.00   800000.00
# 2  Сумма кредита за ТС  1700000.00  1200000.00  1800000.00
# 3    Срок кредита, мес       84.00       84.00       84.00
# 4    Процентная ставка        0.17        0.15        0.14
# 5      Название тарифа        0.00        0.00        0.00
# 'Процентная ставка'

# %%
tbl2 = pd.read_csv('data/table_from_df.csv', index_col=0)
print(tbl2)
lst_from_tbl2 = list(tbl2.loc['Ст-ть авто'])
display(lst_from_tbl2)
tbl2['Значение1']
# Out:
#                       Значение1   Значение2   Значение3
# Парметры
# Ст-ть авто           2500000.00  2000000.00  2600000.00
# ПВ                    800000.00   800000.00   800000.00
# Сумма кредита за ТС  1700000.00  1200000.00  1800000.00
# Срок кредита, мес         84.00       84.00       84.00
# Процентная ставка          0.17        0.15        0.14
# Название тарифа            0.00        0.00        0.00
# [2500000.0, 2000000.0, 2600000.0]
# Парметры
# Ст-ть авто             2500000.00
# ПВ                      800000.00
# Сумма кредита за ТС    1700000.00
# Срок кредита, мес           84.00
# Процентная ставка            0.17
# Название тарифа              0.00
# Name: Значение1, dtype: float64

# %%
# 5. Знакомимся с данными: недвижимость

melb_data = pd.read_csv('data/melb_data.csv', sep=',')
display(melb_data)
# Out:
#        index         Suburb           Address  Rooms Type      Price Method  \
# 0          0     Abbotsford      85 Turner St      2    h  1480000.0      S
# 1          1     Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2          2     Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3          3     Abbotsford  40 Federation La      3    h   850000.0     PI
# 4          4     Abbotsford       55a Park St      4    h  1600000.0     VB
# ...      ...            ...               ...    ...  ...        ...    ...
# 13575  13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576  13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577  13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578  13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579  13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
# ...

# %%
melb_data.loc[15, 'Price']
melb_data.loc[90, 'Date']

round(melb_data.loc[3521, 'Landsize'] / melb_data.loc[1690, 'Landsize'], 0)
# Out:
# 3.0

# %%
# 6. Исследование структуры DataFrame

melb_data.head()
melb_data.tail(n=1)
# Out:
#        index      Suburb     Address  Rooms Type      Price Method  SellerG  \
# 13579  13579  Yarraville  6 Agnes St      4    h  1285000.0     SP  Village
#
#              Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 13579  26/08/2017       6.3  ...  1.0     362.0         112.0     1920.0
#
#        CouncilArea  Lattitude  Longtitude            Regionname  \
# 13579          NaN  -37.81188   144.88449  Western Metropolitan
#
#        Propertycount           Coordinates
# 13579         6543.0  -37.81188, 144.88449
#
# [1 rows x 23 columns]

# %%
melb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Address        13580 non-null  object
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  object
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  object
#  7   SellerG        13580 non-null  object
#  8   Date           13580 non-null  object
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  float64
#  12  Bathroom       13580 non-null  float64
#  13  Car            13580 non-null  int64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  float64
# ...

# %%
melb_data['Car'] = melb_data['Car'].astype('int64')
melb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Address        13580 non-null  object
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  object
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  object
#  7   SellerG        13580 non-null  object
#  8   Date           13580 non-null  object
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  float64
#  12  Bathroom       13580 non-null  float64
#  13  Car            13580 non-null  int64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  float64
# ...

# %%
melb_data.describe().loc[:, ['Distance', 'BuildingArea', 'Price']]
# Out:
#            Distance  BuildingArea         Price
# count  13580.000000  13580.000000  1.358000e+04
# mean      10.137776    139.633972  1.075684e+06
# std        5.868725    392.217403  6.393107e+05
# min        0.000000      0.000000  8.500000e+04
# 25%        6.100000    122.000000  6.500000e+05
# 50%        9.200000    126.000000  9.030000e+05
# 75%       13.000000    129.940000  1.330000e+06
# max       48.100000  44515.000000  9.000000e+06

# %%
melb_data.describe(include='object')
# Out:
#            Suburb           Address   Type Method SellerG        Date  \
# count       13580             13580  13580  13580   13580       13580
# unique        314             13378      3      5     268          58
# top     Reservoir  36 Aberfeldie St      h      S  Nelson  27/05/2017
# freq          359                 3   9449   9022    1565         473
#
#        CouncilArea             Regionname         Coordinates
# count        12211                  13580               13580
# unique          33                      8               13097
# top       Moreland  Southern Metropolitan  -37.8361, 144.9966
# freq          1163                   4695                  12

# %%
melb_data['Regionname'].value_counts()
# Out:
# Southern Metropolitan         4695
# Northern Metropolitan         3890
# Western Metropolitan          2948
# Eastern Metropolitan          1471
# South-Eastern Metropolitan     450
# Eastern Victoria                53
# Northern Victoria               41
# Western Victoria                32
# Name: Regionname, dtype: int64

# %%
melb_data['Coordinates'].info()
melb_data['CouncilArea'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 13580 entries, 0 to 13579
# Series name: Coordinates
# Non-Null Count  Dtype
# --------------  -----
# 13580 non-null  object
# dtypes: object(1)
# memory usage: 106.2+ KB
# <class 'pandas.core.series.Series'>
# RangeIndex: 13580 entries, 0 to 13579
# Series name: CouncilArea
# Non-Null Count  Dtype
# --------------  -----
# 12211 non-null  object
# dtypes: object(1)
# memory usage: 106.2+ KB

# %%
melb_data.describe(include='object').loc[:, ['CouncilArea']].loc['count', 'CouncilArea']
# display(melb_data['CouncilArea'].value_counts())
# Out:
# 12211

# %%
melb_data.describe(include='object')
melb_data.shape[0] - melb_data.describe(include='object').loc[:, ['CouncilArea']].loc['count', 'CouncilArea']
# Out:
# 1369

# %%
melb_data['Car'] = melb_data['Car'].astype('int64')
melb_data['Bedroom'] = melb_data['Bedroom'].astype('int64')
melb_data['Bathroom'] = melb_data['Bathroom'].astype('int64')
melb_data['Propertycount'] = melb_data['Propertycount'].astype('int64')
melb_data['YearBuilt'] = melb_data['YearBuilt'].astype('int64')
melb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Address        13580 non-null  object
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  object
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  object
#  7   SellerG        13580 non-null  object
#  8   Date           13580 non-null  object
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  int64
#  12  Bathroom       13580 non-null  int64
#  13  Car            13580 non-null  int64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  int64
# ...

# %%
melb_data.describe(include='int64').shape
# Out:
# (8, 8)

# %%
melb_data.describe()
# Out:
#               index         Rooms         Price      Distance      Postcode  \
# count  13580.000000  13580.000000  1.358000e+04  13580.000000  13580.000000
# mean    6789.500000      2.937997  1.075684e+06     10.137776   3105.301915
# std     3920.352663      0.955748  6.393107e+05      5.868725     90.676964
# min        0.000000      1.000000  8.500000e+04      0.000000   3000.000000
# 25%     3394.750000      2.000000  6.500000e+05      6.100000   3044.000000
# 50%     6789.500000      3.000000  9.030000e+05      9.200000   3084.000000
# 75%    10184.250000      3.000000  1.330000e+06     13.000000   3148.000000
# max    13579.000000     10.000000  9.000000e+06     48.100000   3977.000000
#
#             Bedroom      Bathroom           Car       Landsize  BuildingArea  \
# count  13580.000000  13580.000000  13580.000000   13580.000000  13580.000000
# mean       2.914728      1.534242      1.611856     558.416127    139.633972
# ...

# %%
melb_data['Regionname'].value_counts()
melb_data['Regionname'].value_counts().shape
display(melb_data.describe(include='object').loc[:, 'Regionname'])
# display(melb_data.describe(include='object').loc[:, 'Suburb'])
# melb_data['Suburb'].value_counts()
melb_data['Regionname'].value_counts()
display(melb_data)
melb_data['Coordinates'].value_counts()
display(melb_data['Address'].describe())
display(melb_data['Coordinates'].describe())
display(melb_data['Suburb'].describe())
# Out:
# count                     13580
# unique                        8
# top       Southern Metropolitan
# freq                       4695
# Name: Regionname, dtype: object
#        index         Suburb           Address  Rooms Type      Price Method  \
# 0          0     Abbotsford      85 Turner St      2    h  1480000.0      S
# 1          1     Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2          2     Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3          3     Abbotsford  40 Federation La      3    h   850000.0     PI
# 4          4     Abbotsford       55a Park St      4    h  1600000.0     VB
# ...      ...            ...               ...    ...  ...        ...    ...
# 13575  13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576  13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577  13577   Williamstown       83 Power St      3    h  1170000.0      S
# ...

# %%
display(round(melb_data['Type'].value_counts(normalize=True)['t']*100))
# Out:
# 8

# %%
# 7. Статистические методы

melb_ser_count = melb_data.count()
display(melb_ser_count)
melb_ser_count.loc['CouncilArea']
melb_ser_count.iloc[-6]
# Out:
# index            13580
# Suburb           13580
# Address          13580
# Rooms            13580
# Type             13580
# Price            13580
# Method           13580
# SellerG          13580
# Date             13580
# Distance         13580
# Postcode         13580
# Bedroom          13580
# Bathroom         13580
# Car              13580
# Landsize         13580
# BuildingArea     13580
# YearBuilt        13580
# CouncilArea      12211
# Lattitude        13580
# Longtitude       13580
# Regionname       13580
# Propertycount    13580
# Coordinates      13580
# dtype: int64
# 13580

# %%
melb_data['CouncilArea'].count()
# Out:
# 12211

# %%
print(melb_data['Price'].mean())
print(melb_data['Car'].max())
# Out:
# 1075684.079455081
# 10

# %%
rate = 0.12
print(round(melb_data['Price'].sum() * rate, 2))
# Out:
# 1752934775.88

# %%
landsize_median = melb_data['Landsize'].median()
landsize_mean = melb_data['Landsize'].mean()
print(abs(landsize_median - landsize_mean)/landsize_mean)
# Out:
# 0.21205713983546193

# %%
print(melb_data['Rooms'].mode())
print(melb_data['Regionname'].mode())
# Out:
# 0    3
# Name: Rooms, dtype: int64
# 0    Southern Metropolitan
# Name: Regionname, dtype: object

# %%
# 8. Фильтрация данных в DataFrame

mask = melb_data['Price'] > 2000000
display(mask)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13575    False
# 13576    False
# 13577    False
# 13578     True
# 13579    False
# Name: Price, Length: 13580, dtype: bool

# %%
display(melb_data[mask].head())
# Out:
#     index       Suburb               Address  Rooms Type      Price Method  \
# 80     80  Albert Park  112 Beaconsfield Pde      3    h  2850000.0     PI
# 85     85  Albert Park     104 Richardson St      4    h  2300000.0      S
# 88     88  Albert Park        29 Faussett St      2    h  2120000.0      S
# 92     92  Albert Park           2 Dundas Pl      3    h  2615000.0      S
# 93     93  Albert Park          23 Finlay St      5    h  2100000.0      S
#
#      SellerG        Date  Distance  ...  Car  Landsize  BuildingArea  \
# 80    Buxton   4/03/2017       3.3  ...    0     211.0         198.0
# 85  Marshall   7/05/2016       3.3  ...    1     153.0         180.0
# 88      Greg  10/09/2016       3.3  ...    1     199.0         107.0
# 92    Cayzer  10/12/2016       3.3  ...    1     177.0         181.0
# 93      Greg  10/12/2016       3.3  ...    1     237.0         126.0
#
#     YearBuilt   CouncilArea  Lattitude  Longtitude             Regionname  \
# ...

# %%
melb_data[melb_data['Price'] > 2000000]
# Out:
#        index          Suburb               Address  Rooms Type      Price  \
# 80        80     Albert Park  112 Beaconsfield Pde      3    h  2850000.0
# 85        85     Albert Park     104 Richardson St      4    h  2300000.0
# 88        88     Albert Park        29 Faussett St      2    h  2120000.0
# 92        92     Albert Park           2 Dundas Pl      3    h  2615000.0
# 93        93     Albert Park          23 Finlay St      5    h  2100000.0
# ...      ...             ...                   ...    ...  ...        ...
# 13521  13521  Port Melbourne          44 Garton St      4    t  2455000.0
# 13523  13523         Prahran        69 Greville St      4    h  2668000.0
# 13553  13553    Surrey Hills          20 Albert Cr      4    h  2720000.0
# 13555  13555    Surrey Hills              3 Oak St      4    h  3100000.0
# 13578  13578    Williamstown          96 Verdon St      4    h  2500000.0
#
#       Method   SellerG        Date  Distance  ...  Car  Landsize  \
# ...

# %%
melb_data[melb_data['Rooms'] == 3].shape[0]
# Out:
# 5881

# %%
melb_data[(melb_data['Rooms'] == 3) & (melb_data['Price'] < 300000)].shape[0]
# Out:
# 3

# %%
melb_data[(melb_data['Price'] < 300000) & ((melb_data['Rooms'] == 3) | (melb_data['BuildingArea'] > 100))].shape[0]
# Out:
# 68

# %%
# Давайте найдём максимальное количество комнат в таунхаусах. 
melb_data[melb_data['Type'] == 't']['Rooms'].max()
# Out:
# 5

# %%
# Найдём медианную площадь здания у объектов, чья цена выше средней

mean_price = melb_data['Price'].mean()
melb_data[melb_data['Price'] > mean_price]['BuildingArea'].median()
# Out:
# 126.0
